# %%
import pandas as pd
# from plotnine import *

# %matplotlib inline

# %%
data = pd.read_csv('../datasets/gamedetails.csv')
playerInfo = pd.read_csv('../datasets/playersinfo.csv')

# %%
print(data.shape)
print(playerInfo.shape)
# data.head()
col = data.columns[1:]
data = data[col].copy()

playerInfoCol = playerInfo.columns[1:]
playerInfo = playerInfo[playerInfoCol].copy()
# Out:
# (44514, 22)
# (132, 9)

# %%
data.describe()
# Out:
#              gameId        teamId        points      playerId           fgm  \
# count  44514.000000  44514.000000  44514.000000  44514.000000  44514.000000
# mean    5121.639641     19.316732      8.681875    478.467089      3.204857
# std      467.011351     11.540629      8.530190    331.967428      3.176252
# min     4308.000000      1.000000      0.000000      1.000000      0.000000
# 25%     4725.000000      9.000000      1.000000    206.000000      0.000000
# 50%     5172.000000     20.000000      7.000000    398.000000      3.000000
# 75%     5522.000000     27.000000     14.000000    776.000000      5.000000
# max     6221.000000     93.000000     61.000000   1844.000000     21.000000
#
#                 fga           ftm           fta           tpm           tpa  \
# count  44514.000000  44514.000000  44514.000000  44514.000000  44514.000000
# mean       6.970167      1.386350      1.807589      0.885811      2.509615
# std        6.117571      2.155063      2.635619      1.327951      2.864058
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        6.000000      0.000000      0.000000      0.000000      2.000000
# 75%       11.000000      2.000000      3.000000      1.000000      4.000000
# max       40.000000     22.000000     27.000000     14.000000     24.000000
#
#             offReb        defReb       assists        steals        blocks  \
# count  44514.00000  44514.000000  44514.000000  44514.000000  44514.000000
# mean       0.80505      2.728872      1.920407      0.592712      0.384239
# std        1.30888      2.821097      2.453618      0.912744      0.780321
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        0.00000      0.000000      0.000000      0.000000      0.000000
# 50%        0.00000      2.000000      1.000000      0.000000      0.000000
# 75%        1.00000      4.000000      3.000000      1.000000      1.000000
# max       12.00000     23.000000     24.000000      8.000000      9.000000
#
#              pFouls     turnovers     plusMinus       minutes       seconds
# count  44514.000000  44514.000000  44514.000000  44514.000000  44514.000000
# mean       1.634609      1.054500     -0.000045     18.450982     24.620704
# std        1.532402      1.350789     10.318568     12.494288     19.267475
# min        0.000000      0.000000    -47.000000      0.000000      0.000000
# 25%        0.000000      0.000000     -6.000000      7.000000      5.000000
# 50%        1.000000      1.000000      0.000000     20.000000     23.000000
# 75%        3.000000      2.000000      5.000000     29.000000     42.000000
# max        6.000000     11.000000     50.000000     64.000000     59.000000

# %%
## make sure gameId, teamId, and playerId as index/primary keys
data = data.groupby(['gameId', 'teamId', 'playerId']).max().reset_index()

# %%
data
# Out:
#        gameId  teamId  playerId  points    min  fgm  fga  ftm  fta  tpm  ...  \
# 0        4308      18       688       4  24:44    1    8    2    3    0  ...
# 1        4308      18       706      19  39:29    6   22    4    4    3  ...
# 2        4308      18       709       2  12:20    0    3    2    2    0  ...
# 3        4308      18      1091       0   0:21    0    0    0    0    0  ...
# 4        4308      18      1092       2  11:54    1    2    0    0    0  ...
# ...       ...     ...       ...     ...    ...  ...  ...  ...  ...  ...  ...
# 35533    6221      38       434       0  10:50    0    2    0    0    0  ...
# 35534    6221      38       479      26  46:10   10   17    3    4    3  ...
# 35535    6221      38       527      22  33:48    6   14    5    5    5  ...
# 35536    6221      38       732       0   0:00    0    0    0    0    0  ...
# 35537    6221      38       837       0   0:00    0    0    0    0    0  ...
#
#        offReb  defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  \
# 0           1       2        1       4       0       2          1        -16
# 1           0       3        5       4       0       4          5        -12
# 2           1       1        0       0       0       4          1         -9
# 3           0       0        0       0       0       0          0          0
# 4           0       0        2       0       0       0          1        -11
# ...       ...     ...      ...     ...     ...     ...        ...        ...
# 35533       0       1        0       0       0       2          1          5
# 35534       2       8        3       1       1       2          2          2
# 35535       1       1        0       1       0       1          1        -10
# 35536       0       0        0       0       0       0          0          0
# 35537       0       0        0       0       0       0          0          0
#
#        minutes  seconds
# 0           24       44
# 1           39       29
# 2           12       20
# 3            0       21
# 4           11       54
# ...        ...      ...
# 35533       10       50
# 35534       46       10
# 35535       33       48
# 35536        0        0
# 35537        0        0
#
# [35538 rows x 21 columns]

# %%
data["playerId"].value_counts()
# Out:
# 479     110
# 184     109
# 203     108
# 581     108
# 514     107
#        ...
# 1123      1
# 1155      1
# 1151      1
# 1795      1
# 1807      1
# Name: playerId, Length: 768, dtype: int64

# %%
# look at team 
# data["teamId"].value_counts()
# data.groupby(['gameId', 'teamId']).agg('count')
data.groupby(['teamId']).agg('count')['gameId'].sort_values()
# Out:
# teamId
# 39      10
# 42      10
# 92      11
# 90      12
# 12      12
# 33      12
# 87      13
# 35      13
# 34      14
# 32      15
# 91      20
# 18      27
# 93      31
# 13      32
# 6     1222
# 7     1324
# 28    1336
# 4     1338
# 8     1343
# 1     1347
# 17    1349
# 24    1357
# 41    1367
# 19    1400
# 5     1411
# 40    1412
# 23    1413
# 25    1425
# 20    1440
# 15    1451
# 22    1452
# 27    1463
# 21    1477
# 30    1494
# 10    1516
# 14    1527
# 31    1543
# 26    1550
# 2     1628
# 16    1631
# 9     1645
# 29    1748
# 38    1824
# 11    1849
# Name: gameId, dtype: int64

# %%
nonNba = [39, 42, 92, 90, 12, 33, 87, 35, 34, 32, 91, 18, 93, 13]

# %%
# byGame_n_team = data.groupby(['gameId', 'teamId']).agg('sum').reset_index()
byGame_n_team = data.groupby(['gameId', 'teamId']).sum().reset_index()

# %%
# check all gameId has 2 teams
game_by_team = byGame_n_team['gameId'].value_counts().tolist()

# %%
for g in game_by_team:
    if g != 2:
        print(g)

# yaay ! none means no anomaly

# %%
# but somehow we got repeated playerId. so have to get rid of the dups
# issue is from the data, not the script. script has to make sure no dups. 
byGame_n_team.groupby(['gameId', 'teamId', 'playerId']).sum()
# Out:
#                         points  fgm  fga  ftm  fta  tpm  tpa  offReb  defReb  \
# gameId teamId playerId
# 4308   18     13058         84   31   82   13   14    9   33       8      29
#        27     9575         104   41   85   16   25    6   29      11      37
# 4309   2      13534         97   36  104   16   22    9   47      11      45
#        5      11722        104   34   89   25   39   11   36      12      53
# 4310   29     8825         104   37   88   18   25   12   31      11      35
# ...                        ...  ...  ...  ...  ...  ...  ...     ...     ...
# 6219   38     4850         105   36   86   23   24   10   32       6      32
# 6220   11     4496         106   38   82   10   14   20   42       6      31
#        38     5223         105   38   85   21   27    8   32      13      30
# 6221   11     5310         110   39   80   21   30   11   31      11      31
#        38     5315         114   39   82   23   29   13   33      11      28
#
#                         assists  steals  blocks  pFouls  turnovers  plusMinus  \
# gameId teamId playerId
# 4308   18     13058          15      10       1      26         20       -100
#        27     9575           25      13       9      19         17        100
# 4309   2      13534          12       9       7      35         12        -35
#        5      11722          17       4       7      22         17         35
# 4310   29     8825           25       4       2      45         24        -90
# ...                         ...     ...     ...     ...        ...        ...
# 6219   38     4850           22      12       4      21          9         65
# 6220   11     4496           27       5       7      22         15          5
#        38     5223           19       6       5      19         13         -5
# 6221   11     5310           28       9       6      23         16        -20
#        38     5315           25       8       2      23         12         20
#
#                         minutes  seconds
# gameId teamId playerId
# 4308   18     13058         233      419
#        27     9575          235      300
# 4309   2      13534         235      300
#        5      11722         235      299
# 4310   29     8825          234      360
# ...                         ...      ...
# 6219   38     4850          234      360
# 6220   11     4496          235      298
#        38     5223          236      239
# 6221   11     5310          234      357
#        38     5315          236      239
#
# [2762 rows x 17 columns]

# %%
# byGame_n_team[byGame_n_team["gameId"] == 5567]
data[(data["gameId"] == 6196) & (data["teamId"] == 29) & (data["playerId"] == 12)]
# data[(data["gameId"] == 4308) & (data["teamId"] == 18) & (data["playerId"] == 688)]
# Out:
#        gameId  teamId  playerId  points    min  fgm  fga  ftm  fta  tpm  ...  \
# 35162    6196      29        12       9  19:36    3    8    2    2    1  ...
#
#        offReb  defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  \
# 35162       1       5        1       0       0       2          1         -2
#
#        minutes  seconds
# 35162       19       36
#
# [1 rows x 21 columns]

# %%
# sort df by gameId, teamId
byGame_n_team.sort_values(["gameId", "teamId"], inplace=True)
# get opp team id, we have to get pts diff
byGame_n_team["oppTeamId"] = byGame_n_team.diff()["gameId"]

# %%
byGame_n_team[byGame_n_team["oppTeamId"] > 1]
# Out:
#       gameId  teamId  playerId  points  fgm  fga  ftm  fta  tpm  tpa  ...  \
# 664     4651       4      3037     102   33   79   22   26   14   45  ...
# 1492    5066      10      5222     101   36   82   19   25   10   29  ...
# 2594    5712      34      4545     164   66  140    5    7   27   77  ...
# 2598    5715       4      5069     111   38   88   24   26   11   26  ...
# 2670    5753      11      5346     121   43   96   20   22   15   39  ...
# 2674    5757       9      5475     103   44   96    9   12    6   24  ...
# 2676    5761      11      5346     129   47   89   25   31   10   30  ...
# 2678    6126       9      5475      90   35   88   18   23    2   20  ...
# 2680    6152      27      5869      95   35   89   14   21   11   32  ...
# 2702    6164      27      4771      90   28   65   25   30    9   27  ...
# 2704    6167      11      5346     104   38   75   21   27    7   22  ...
# 2716    6178       9      5475     121   41   81   27   31   12   29  ...
# 2730    6195      11      5474     116   42   84   15   18   17   33  ...
# 2738    6202      21      4131     108   37   93   23   27   11   44  ...
# 2750    6216      11      5310     109   34   78   29   31   12   31  ...
#
#       defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  minutes  \
# 664       37       26       2       4      22         18        -50      234
# 1492      33       21       6       2      23         14        -10      235
# 2594      45       43       8       1       6         12        -70      234
# 2598      35       15       9       2      27         11         45      235
# 2670      24       31       7       3      23          8        -40      236
# 2674      25       26       5       3      18          7        -85      233
# 2676      39       32       6       9      24         10         95      235
# 2678      40       21       3       8      19          6         20      235
# 2680      34       23       5       2      21         14        -65      234
# 2702      36       16       4       7      21         15        -10      236
# 2704      30       24       7       3      24         20         20      236
# 2716      27       22      12       7      22         12         40      235
# 2730      31       30      13       8      24         14        110      232
# 2738      45       21       8      11      16         12         40      235
# 2750      29       29       6       2      27         16        -45      236
#
#       seconds  oppTeamId
# 664       360       12.0
# 1492      300        2.0
# 2594      360       96.0
# 2598      300        2.0
# 2670      240        3.0
# 2674      420        3.0
# 2676      300        4.0
# 2678      300      365.0
# 2680      360       26.0
# 2702      236        2.0
# 2704      240        3.0
# 2716      300        6.0
# 2730      478       11.0
# 2738      296        4.0
# 2750      237        9.0
#
# [15 rows x 21 columns]

# %%
byGame_n_team.isnull().sum()
# byGame_n_team.isnull().values
byGame_n_team[byGame_n_team["points"] > 200]
# Out:
# Empty DataFrame
# Columns: [gameId, teamId, playerId, points, fgm, fga, ftm, fta, tpm, tpa, offReb, defReb, assists, steals, blocks, pFouls, turnovers, plusMinus, minutes, seconds, oppTeamId]
# Index: []
#
# [0 rows x 21 columns]

# %%
byGame_n_team.fillna(1, inplace=True)

# %%
# convert oppTeamId to int 
print(byGame_n_team["oppTeamId"].dtypes)
byGame_n_team["oppTeamId"] = byGame_n_team["oppTeamId"].astype('int32')
print(byGame_n_team["oppTeamId"].dtypes)
# Out:
# float64
# int32

# %%
byGame_n_team.loc[664:665]
# Out:
#      gameId  teamId  points  playerId  fgm  fga  ftm  fta  tpm  tpa  ...  \
# 664    4651       4     102      3037   33   79   22   26   14   45  ...
# 665    4651      22     112      5900   44   92   15   17    9   25  ...
#
#      defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  minutes  \
# 664      37       26       2       4      22         18        -50      234
# 665      29       25      15       4      20          7         50      236
#
#      seconds  oppTeamId
# 664      360       12.0
# 665      240        0.0
#
# [2 rows x 21 columns]

# %%
byGame_n_team[byGame_n_team["gameId"] == 6216]
# Out:
#       gameId  teamId  points  playerId  fgm  fga  ftm  fta  tpm  tpa  ...  \
# 2750    6216      11     109      5310   34   78   29   31   12   31  ...
# 2751    6216      38     118      4955   39   77   27   32   13   33  ...
#
#       defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  minutes  \
# 2750      29       29       6       2      27         16        -45      236
# 2751      29       25       6       6      26         10         45      236
#
#       seconds  oppTeamId
# 2750      237        9.0
# 2751      239        0.0
#
# [2 rows x 21 columns]

# %%
byGame_n_team['oppTeamId'].value_counts()
# Out:
# 0      1381
# 1      1366
# 3         3
# 2         3
# 4         2
# 365       1
# 11        1
# 9         1
# 96        1
# 26        1
# 12        1
# 6         1
# Name: oppTeamId, dtype: int64

# %%
byGame_n_team[['gameId', 'teamId', 'points','oppTeamId']]
# Out:
#       gameId  teamId  points  oppTeamId
# 0       4308      18      84        1.0
# 1       4308      27     104        0.0
# 2       4309       2      97        1.0
# 3       4309       5     104        0.0
# 4       4310      29     104        1.0
# ...      ...     ...     ...        ...
# 2757    6219      38     105        0.0
# 2758    6220      11     106        1.0
# 2759    6220      38     105        0.0
# 2760    6221      11     110        1.0
# 2761    6221      38     114        0.0
#
# [2762 rows x 4 columns]

# %% [markdown]
# ## 1 gameId per row
# 1. separate home team from away team into 2 different dfs
# 2. merge these 2 dfs into 1 df

# %%
# separate home team from away team
home = byGame_n_team[byGame_n_team['oppTeamId'] >= 1].copy()
away = byGame_n_team[byGame_n_team['oppTeamId'] < 1].copy()

# %%
print(home.head())
print("==========================================================")
print(away.head())
# Out:
#    gameId  teamId  points  playerId  fgm  fga  ftm  fta  tpm  tpa  ...  \
# 0    4308      18      84     13058   31   82   13   14    9   33  ...
# 2    4309       2      97     13534   36  104   16   22    9   47  ...
# 4    4310      29     104      8825   37   88   18   25   12   31  ...
# 6    4311       8     116     12360   39   75   23   36   15   27  ...
# 8    4312      11     110      8305   44   93   10   13   12   34  ...
#
#    defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  minutes  \
# 0      29       15      10       1      26         20       -100      233
# 2      45       12       9       7      35         12        -35      235
# 4      35       25       4       2      45         24        -90      234
# 6      39       31       6      10      29         13        265      232
# 8      41       33       9       8      23         17        -20      231
#
#    seconds  oppTeamId
# 0      419          1
# 2      300          1
# 4      360          1
# 6      480          1
# 8      539          1
#
# [5 rows x 21 columns]
# ==========================================================
#    gameId  teamId  points  playerId  fgm  fga  ftm  fta  tpm  tpa  ...  \
# 1    4308      27     104      9575   41   85   16   25    6   29  ...
# 3    4309       5     104     11722   34   89   25   39   11   36  ...
# 5    4310      38     122      8693   34   82   42   51   12   35  ...
# 7    4311      91      63     21783   17   71   23   31    6   23  ...
# 9    4312      22     114      9997   40   94   22   30   12   30  ...
#
#    defReb  assists  steals  blocks  pFouls  turnovers  plusMinus  minutes  \
# 1      37       25      13       9      19         17        100      235
# 3      53       17       4       7      22         17         35      235
# 5      33       15       8       6      28         15         90      231
# 7      22       12       4       2      32         17       -265      231
# 9      36       15      11       6      16         15         20      234
#
#    seconds  oppTeamId
# 1      300          0
# 3      299          0
# 5      540          0
# 7      539          0
# 9      360          0
#
# [5 rows x 21 columns]

# %%
result = pd.merge(home, away, how="outer", left_on=["gameId"], right_on=["gameId"])

# %%
result[result["gameId"] == 6219]
# Out:
#       gameId  teamId_x  playerId_x  points_x  fgm_x  fga_x  ftm_x  fta_x  \
# 1378    6219        11        5310        92     35     78     14     21
#
#       tpm_x  tpa_x  ...  defReb_y  assists_y  steals_y  blocks_y  pFouls_y  \
# 1378      8     27  ...        32         22        12         4        21
#
#       turnovers_y  plusMinus_y  minutes_y  seconds_y  oppTeamId_y
# 1378            9           65        234        360            0
#
# [1 rows x 41 columns]

# %%
# check to make sure we dont get double gameId
print(result["gameId"].value_counts().shape)
print(byGame_n_team["gameId"].value_counts().shape)
# Out:
# (1381,)
# (1381,)

# %%
result
# Out:
#       gameId  teamId_x  playerId_x  points_x  fgm_x  fga_x  ftm_x  fta_x  \
# 0       4308        18       13058        84     31     82     13     14
# 1       4309         2       13534        97     36    104     16     22
# 2       4310        29        8825       104     37     88     18     25
# 3       4311         8       12360       116     39     75     23     36
# 4       4312        11        8305       110     44     93     10     13
# ...      ...       ...         ...       ...    ...    ...    ...    ...
# 1376    6217        11        5310       109     38     82     20     23
# 1377    6218        11        5269       109     36     91     25     30
# 1378    6219        11        5310        92     35     78     14     21
# 1379    6220        11        4496       106     38     82     10     14
# 1380    6221        11        5310       110     39     80     21     30
#
#       tpm_x  tpa_x  ...  defReb_y  assists_y  steals_y  blocks_y  pFouls_y  \
# 0         9     33  ...        37         25        13         9        19
# 1         9     47  ...        53         17         4         7        22
# 2        12     31  ...        33         15         8         6        28
# 3        15     27  ...        22         12         4         2        32
# 4        12     34  ...        36         15        11         6        16
# ...     ...    ...  ...       ...        ...       ...       ...       ...
# 1376     13     34  ...        34         17         8         2        22
# 1377     12     36  ...        35         30         9        10        22
# 1378      8     27  ...        32         22        12         4        21
# 1379     20     42  ...        30         19         6         5        19
# 1380     11     31  ...        28         25         8         2        23
#
#       turnovers_y  plusMinus_y  minutes_y  seconds_y  oppTeamId_y
# 0              17          100        235        300            0
# 1              17           35        235        299            0
# 2              15           90        231        540            0
# 3              17         -265        231        539            0
# 4              15           20        234        360            0
# ...           ...          ...        ...        ...          ...
# 1376           15          -25        236        238            0
# 1377           14           70        234        357            0
# 1378            9           65        234        360            0
# 1379           13           -5        236        239            0
# 1380           12           20        236        239            0
#
# [1381 rows x 41 columns]

# %%
# get diff _x vs _y
cols = list()
for c in result.columns:
    if ("_x") in c:
        cols.append(c[:c.index("_x")])

# %%
dat = list()
for i, row in result.iterrows():
#     row["win"] = 1
    for c in cols:
#         row[c + "_delta"] = abs(row[c + "_x"] - row[c + "_y"])
        row[c + "_delta"] = row[c + "_x"] - row[c + "_y"]
#         if c == "points":
#             if row[c + "_x"] < row[c + "_y"]:
#                 row["win"] = 0
    dat.append(row)

# %%
data_xy = pd.DataFrame(dat)

# %%
data_xy
# Out:
#       gameId  teamId_x  playerId_x  points_x  fgm_x  fga_x  ftm_x  fta_x  \
# 0       4308        18       13058        84     31     82     13     14
# 1       4309         2       13534        97     36    104     16     22
# 2       4310        29        8825       104     37     88     18     25
# 3       4311         8       12360       116     39     75     23     36
# 4       4312        11        8305       110     44     93     10     13
# ...      ...       ...         ...       ...    ...    ...    ...    ...
# 1376    6217        11        5310       109     38     82     20     23
# 1377    6218        11        5269       109     36     91     25     30
# 1378    6219        11        5310        92     35     78     14     21
# 1379    6220        11        4496       106     38     82     10     14
# 1380    6221        11        5310       110     39     80     21     30
#
#       tpm_x  tpa_x  ...  defReb_delta  assists_delta  steals_delta  \
# 0         9     33  ...            -8            -10            -3
# 1         9     47  ...            -8             -5             5
# 2        12     31  ...             2             10            -4
# 3        15     27  ...            17             19             2
# 4        12     34  ...             5             18            -2
# ...     ...    ...  ...           ...            ...           ...
# 1376     13     34  ...             2             17            -1
# 1377     12     36  ...            -7             -5            -1
# 1378      8     27  ...             2              4            -6
# 1379     20     42  ...             1              8            -1
# 1380     11     31  ...             3              3             1
#
#       blocks_delta  pFouls_delta  turnovers_delta  plusMinus_delta  \
# 0               -8             7                3             -200
# 1                0            13               -5              -70
# 2               -4            17                9             -180
# 3                8            -3               -4              530
# 4                2             7                2              -40
# ...            ...           ...              ...              ...
# 1376             3             4                0               50
# 1377            -7            -1                0             -140
# 1378             2             2                8             -130
# 1379             2             3                2               10
# 1380             4             0                4              -40
#
#       minutes_delta  seconds_delta  oppTeamId_delta
# 0                -2            119                1
# 1                 0              1                1
# 2                 3           -180                1
# 3                 1            -59                1
# 4                -3            179                1
# ...             ...            ...              ...
# 1376              0             -2                1
# 1377              0              2                1
# 1378              0             -1                1
# 1379             -1             59                1
# 1380             -2            118                1
#
# [1381 rows x 61 columns]

# %%
cols = [
    'gameId',
    'teamId_x',
    'teamId_y',
    'points_delta',
    'playerId_delta', 
    'fgm_delta',
    'fga_delta', 
    'ftm_delta', 
    'fta_delta', 
    'tpm_delta', 
    'tpa_delta',
    'offReb_delta', 
    'defReb_delta', 
    'assists_delta', 
    'steals_delta',
    'blocks_delta', 
    'pFouls_delta', 
    'turnovers_delta', 
    'plusMinus_delta',
    'minutes_delta', 
    'seconds_delta',
]

games = data_xy[cols].copy()

# %%
games
# Out:
#       gameId  teamId_x  teamId_y  points_delta  playerId_delta  fgm_delta  \
# 0       4308        18        27           -20            3483        -10
# 1       4309         2         5            -7            1812          2
# 2       4310        29        38           -18             132          3
# 3       4311         8        91            53           -9423         22
# 4       4312        11        22            -4           -1692          4
# ...      ...       ...       ...           ...             ...        ...
# 1376    6217        11        38             5              87          3
# 1377    6218        11        38           -14             -46         -7
# 1378    6219        11        38           -13             460         -1
# 1379    6220        11        38             1            -727          0
# 1380    6221        11        38            -4              -5          0
#
#       fga_delta  ftm_delta  fta_delta  tpm_delta  ...  offReb_delta  \
# 0            -3         -3        -11          3  ...            -3
# 1            15         -9        -17         -2  ...            -1
# 2             6        -24        -26          0  ...            -1
# 3             4          0          5          9  ...             1
# 4            -1        -12        -17          0  ...            -4
# ...         ...        ...        ...        ...  ...           ...
# 1376        -12         -3         -3          2  ...            -9
# 1377          9          5          9         -5  ...             8
# 1378         -8         -9         -3         -2  ...             2
# 1379         -3        -11        -13         12  ...            -7
# 1380         -2         -2          1         -2  ...             0
#
#       defReb_delta  assists_delta  steals_delta  blocks_delta  pFouls_delta  \
# 0               -8            -10            -3            -8             7
# 1               -8             -5             5             0            13
# 2                2             10            -4            -4            17
# 3               17             19             2             8            -3
# 4                5             18            -2             2             7
# ...            ...            ...           ...           ...           ...
# 1376             2             17            -1             3             4
# 1377            -7             -5            -1            -7            -1
# 1378             2              4            -6             2             2
# 1379             1              8            -1             2             3
# 1380             3              3             1             4             0
#
#       turnovers_delta  plusMinus_delta  minutes_delta  seconds_delta
# 0                   3             -200             -2            119
# 1                  -5              -70              0              1
# 2                   9             -180              3           -180
# 3                  -4              530              1            -59
# 4                   2              -40             -3            179
# ...               ...              ...            ...            ...
# 1376                0               50              0             -2
# 1377                0             -140              0              2
# 1378                8             -130              0             -1
# 1379                2               10             -1             59
# 1380                4              -40             -2            118
#
# [1381 rows x 21 columns]

# %%
# still have to separate team x and team y.
# team x as it is
# team y = all delta reverse. plus to minus, minus to plus (*-1)
games.columns
# Out:
# Index(['gameId', 'teamId_x', 'teamId_y', 'points_delta', 'playerId_delta',
#        'fgm_delta', 'fga_delta', 'ftm_delta', 'fta_delta', 'tpm_delta',
#        'tpa_delta', 'offReb_delta', 'defReb_delta', 'assists_delta',
#        'steals_delta', 'blocks_delta', 'pFouls_delta', 'turnovers_delta',
#        'plusMinus_delta', 'minutes_delta', 'seconds_delta'],
#       dtype='object')

# %%
team_x_cols = [ 
    'gameId', 
    'teamId_x',
    'points_delta', 
    'playerId_delta',
    'fgm_delta', 
    'fga_delta', 
    'ftm_delta', 
    'fta_delta', 
    'tpm_delta',
    'tpa_delta', 
    'offReb_delta', 
    'defReb_delta', 
    'assists_delta',
    'steals_delta', 
    'blocks_delta', 
    'pFouls_delta', 
    'turnovers_delta',
    'plusMinus_delta', 
    'minutes_delta', 
    'seconds_delta'
    ]

team_y_cols = [ 
    'gameId', 
    'teamId_y',
    'points_delta', 
    'playerId_delta',
    'fgm_delta', 
    'fga_delta', 
    'ftm_delta', 
    'fta_delta', 
    'tpm_delta',
    'tpa_delta', 
    'offReb_delta', 
    'defReb_delta', 
    'assists_delta',
    'steals_delta', 
    'blocks_delta', 
    'pFouls_delta', 
    'turnovers_delta',
    'plusMinus_delta', 
    'minutes_delta', 
    'seconds_delta'
    ]

team_x = games[team_x_cols]
team_y = games[team_y_cols]

# %%
# invert all value for team y
team_y_cols
invert_cols = ['gameId', 'teamId_y']
team_y_invert_cols = list(set(team_y_cols).difference(invert_cols))

# %%
team_y[team_y_invert_cols] = team_y[team_y_invert_cols].apply(lambda x: x*-1)
# Out:
# /home/user/anaconda3/envs/keras/lib/python3.7/site-packages/pandas/core/frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
team_y[team_y['gameId'] == 4308]
# Out:
#    gameId  teamId_y  points_delta  playerId_delta  fgm_delta  fga_delta  \
# 0    4308        27            20           -3483         10          3
#
#    ftm_delta  fta_delta  tpm_delta  tpa_delta  offReb_delta  defReb_delta  \
# 0          3         11         -3         -4             3             8
#
#    assists_delta  steals_delta  blocks_delta  pFouls_delta  turnovers_delta  \
# 0             10             3             8            -7               -3
#
#    plusMinus_delta  minutes_delta  seconds_delta
# 0              200              2           -119

# %%
team_x[team_x['gameId'] == 4308]
# Out:
#    gameId  teamId_x  points_delta  playerId_delta  fgm_delta  fga_delta  \
# 0    4308        18           -20            3483        -10         -3
#
#    ftm_delta  fta_delta  tpm_delta  tpa_delta  offReb_delta  defReb_delta  \
# 0         -3        -11          3          4            -3            -8
#
#    assists_delta  steals_delta  blocks_delta  pFouls_delta  turnovers_delta  \
# 0            -10            -3            -8             7                3
#
#    plusMinus_delta  minutes_delta  seconds_delta
# 0             -200             -2            119

# %%
# update col names
team_x = team_x.rename(columns={'teamId_x': 'teamId'})
team_y = team_y.rename(columns={'teamId_y': 'teamId'})

# %%
all_data_frames = [team_x, team_y]
all_data = pd.concat(all_data_frames)
all_data.drop(['playerId_delta'], axis=1, inplace=True)
# all_data.drop(['playerId_delta','gameId'], axis=1, inplace=True)

# %%
all_data["win"] = all_data["points_delta"].apply(lambda x: 1 if x > 0 else 0)

# %%
print(all_data.shape)
all_data.columns
# Out:
# (2762, 20)
# Index(['gameId', 'teamId', 'points_delta', 'fgm_delta', 'fga_delta',
#        'ftm_delta', 'fta_delta', 'tpm_delta', 'tpa_delta', 'offReb_delta',
#        'defReb_delta', 'assists_delta', 'steals_delta', 'blocks_delta',
#        'pFouls_delta', 'turnovers_delta', 'plusMinus_delta', 'minutes_delta',
#        'seconds_delta', 'win'],
#       dtype='object')

# %%
all_data.head()
# Out:
#    gameId  teamId  points_delta  fgm_delta  fga_delta  ftm_delta  fta_delta  \
# 0    4308      18           -20        -10         -3         -3        -11
# 1    4309       2            -7          2         15         -9        -17
# 2    4310      29           -18          3          6        -24        -26
# 3    4311       8            53         22          4          0          5
# 4    4312      11            -4          4         -1        -12        -17
#
#    tpm_delta  tpa_delta  offReb_delta  defReb_delta  assists_delta  \
# 0          3          4            -3            -8            -10
# 1         -2         11            -1            -8             -5
# 2          0         -4            -1             2             10
# 3          9          4             1            17             19
# 4          0          4            -4             5             18
#
#    steals_delta  blocks_delta  pFouls_delta  turnovers_delta  plusMinus_delta  \
# 0            -3            -8             7                3             -200
# 1             5             0            13               -5              -70
# 2            -4            -4            17                9             -180
# 3             2             8            -3               -4              530
# 4            -2             2             7                2              -40
#
#    minutes_delta  seconds_delta  win
# 0             -2            119    0
# 1              0              1    0
# 2              3           -180    0
# 3              1            -59    1
# 4             -3            179    0

# %%
all_data[all_data['gameId'] == 4308]
# Out:
#    gameId  teamId  points_delta  fgm_delta  fga_delta  ftm_delta  fta_delta  \
# 0    4308      18           -20        -10         -3         -3        -11
# 0    4308      27            20         10          3          3         11
#
#    tpm_delta  tpa_delta  offReb_delta  defReb_delta  assists_delta  \
# 0          3          4            -3            -8            -10
# 0         -3         -4             3             8             10
#
#    steals_delta  blocks_delta  pFouls_delta  turnovers_delta  plusMinus_delta  \
# 0            -3            -8             7                3             -200
# 0             3             8            -7               -3              200
#
#    minutes_delta  seconds_delta  win
# 0             -2            119    0
# 0              2           -119    1

# %%
all_data[all_data['teamId'] == 6]
# Out:
#       gameId  teamId  points_delta  fgm_delta  fga_delta  ftm_delta  \
# 8       4316       6            12          5          2         11
# 21      4329       6           -34        -11         13         -4
# 62      4370       6            15          0         -2         10
# 74      4382       6            -5          3          7        -10
# 92      4400       6           -19          0          8        -18
# ...      ...     ...           ...        ...        ...        ...
# 842     5162       6            -7         -1         -1          0
# 886     5206       6            19          7         -9          4
# 955     5275       6            10          2         -4          4
# 994     5314       6             7         -5         -4         18
# 1012    5332       6            -5          5          3         -2
#
#       fta_delta  tpm_delta  tpa_delta  offReb_delta  defReb_delta  \
# 8             8         -9        -21            -1             8
# 21          -12         -8         -4             1           -22
# 62           12          5          7            -2            -1
# 74          -16         -1          0            -1             1
# 92          -18         -1         -3            -6           -10
# ...         ...        ...        ...           ...           ...
# 842          -4         -5         -8            -1             4
# 886           8          1        -13             2            15
# 955           0          2          1             5            12
# 994          23         -1        -12             2             1
# 1012         -7        -13        -15            -2            -2
#
#       assists_delta  steals_delta  blocks_delta  pFouls_delta  \
# 8                -1             3            -3            -4
# 21               -5             4            -5             7
# 62                1             1             0            -6
# 74               -3            -6             2             8
# 92               -2            -6            -2             6
# ...             ...           ...           ...           ...
# 842              -5            -2             0            -1
# 886               1            -4             4             0
# 955               0            -2            -5             4
# 994              -3            -1            -3            -4
# 1012             -5            -4             0             2
#
#       turnovers_delta  plusMinus_delta  minutes_delta  seconds_delta  win
# 8                  -7              120              4           -239    1
# 21                 -5             -340              0              0    0
# 62                 -4              150             -3            181    1
# 74                  1              -50             -1             62    0
# 92                 -1             -190             -1             59    0
# ...               ...              ...            ...            ...  ...
# 842                 4              -70             -1             60    0
# 886                 5              190              0              0    1
# 955                 6              100             -1             60    1
# 994                -4               70              1            -60    1
# 1012                1              -50             -1             60    0
#
# [86 rows x 20 columns]

# %%
all_data.describe()
# Out:
#             gameId       teamId  points_delta    fgm_delta    fga_delta  \
# count  2762.000000  2762.000000   2762.000000  2762.000000  2762.000000
# mean   5025.013034    19.301231      0.000000     0.000000     0.000000
# std     440.463543    11.623101     15.005203     6.800462     8.814397
# min    4308.000000     1.000000    -58.000000   -29.000000   -40.000000
# 25%    4664.000000     9.000000     -9.000000    -4.000000    -6.000000
# 50%    5009.000000    20.000000      0.000000     0.000000     0.000000
# 75%    5355.000000    27.000000      9.000000     4.000000     6.000000
# max    6221.000000    93.000000     58.000000    29.000000    40.000000
#
#          ftm_delta    fta_delta    tpm_delta    tpa_delta  offReb_delta  \
# count  2762.000000  2762.000000  2762.000000  2762.000000   2762.000000
# mean      0.000000     0.000000     0.000000     0.000000      0.000000
# std       7.617247     9.167127     5.252067    10.215604      5.401115
# min     -26.000000   -30.000000   -23.000000   -51.000000    -22.000000
# 25%      -5.000000    -6.000000    -3.000000    -7.000000     -4.000000
# 50%       0.000000     0.000000     0.000000     0.000000      0.000000
# 75%       5.000000     6.000000     3.000000     7.000000      4.000000
# max      26.000000    30.000000    23.000000    51.000000     22.000000
#
#        defReb_delta  assists_delta  steals_delta  blocks_delta  pFouls_delta  \
# count   2762.000000    2762.000000   2762.000000   2762.000000   2762.000000
# mean       0.000000       0.000000      0.000000      0.000000      0.000000
# std        7.528625       7.154527      3.956299      3.645263      4.904078
# min      -25.000000     -26.000000    -14.000000    -14.000000    -19.000000
# 25%       -5.000000      -5.000000     -3.000000     -2.000000     -3.000000
# 50%        0.000000       0.000000      0.000000      0.000000      0.000000
# 75%        5.000000       5.000000      3.000000      2.000000      3.000000
# max       25.000000      26.000000     14.000000     14.000000     19.000000
#
#        turnovers_delta  plusMinus_delta  minutes_delta  seconds_delta  \
# count      2762.000000      2762.000000     2762.00000    2762.000000
# mean          0.000000         0.000000        0.00000       0.000000
# std           5.073955       149.749843        1.92808      89.115489
# min         -19.000000      -580.000000      -39.00000    -301.000000
# 25%          -3.000000       -90.000000       -1.00000     -60.000000
# 50%           0.000000         0.000000        0.00000       0.000000
# 75%           3.000000        90.000000        1.00000      60.000000
# max          19.000000       580.000000       39.00000     301.000000
#
#                win
# count  2762.000000
# mean      0.500000
# std       0.500091
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %%
all_data[all_data["points_delta"] > 100]
# Out:
# Empty DataFrame
# Columns: [gameId, teamId, points_delta, fgm_delta, fga_delta, ftm_delta, fta_delta, tpm_delta, tpa_delta, offReb_delta, defReb_delta, assists_delta, steals_delta, blocks_delta, pFouls_delta, turnovers_delta, plusMinus_delta, minutes_delta, seconds_delta, win]
# Index: []

# %%
t = all_data.groupby(['teamId', 'win']).agg(
#     win_cnt = pd.NamedAgg(column='win', aggfunc=sum),
    game_cnt = pd.NamedAgg(column='win', aggfunc='count')
).reset_index()

# %%
# all team with only 1 game are non-nba
t[t["game_cnt"] == 1]
# Out:
#     teamId  win  game_cnt
# 20      12    0         1
# 57      32    0         1
# 58      33    0         1
# 59      34    0         1
# 60      35    1         1
# 63      39    1         1
# 68      42    0         1
# 69      87    0         1
# 70      90    0         1
# 71      91    0         1
# 72      92    0         1

# %%
# remove all non nba
nonNba = [39, 42, 92, 90, 12, 33, 87, 35, 34, 32, 91, 18, 93, 13]
all_data = all_data[~all_data["teamId"].isin(nonNba)].copy()

# %%
all_data.groupby(['teamId', 'win']).agg(
#     win_cnt = pd.NamedAgg(column='win', aggfunc=sum),
    game_cnt = pd.NamedAgg(column='win', aggfunc='count')
)
# Out:
#             game_cnt
# teamId win
# 1      0          56
#        1          30
# 2      0          39
#        1          55
# 4      0          45
#        1          45
# 5      0          43
#        1          43
# 6      0          63
#        1          23
# 7      0          64
#        1          21
# 8      0          51
#        1          34
# 9      0          36
#        1          64
# 10     0          47
#        1          43
# 11     0          36
#        1          72
# 14     0          35
#        1          62
# 15     0          40
#        1          50
# 16     0          38
#        1          55
# 17     0          48
#        1          39
# 19     0          52
#        1          34
# 20     0          46
#        1          42
# 21     0          28
#        1          72
# 22     0          49
#        1          37
# 23     0          54
#        1          33
# 24     0          67
#        1          19
# 25     0          38
#        1          52
# 26     0          47
#        1          45
# 27     0          37
#        1          61
# 28     0          64
#        1          21
# 29     0          38
#        1          64
# 30     0          47
#        1          40
# 31     0          39
#        1          54
# 38     0          33
#        1          77
# 40     0          35
#        1          56
# 41     0          51
#        1          36
