# %%
import pandas as pd
from plotnine import *

# %matplotlib inline

# %%
data = pd.read_csv("sample.csv")

# %%
data
# Out:
#                          DATASET   GAME-ID        DATE  PLAYER-ID  \
# 0   NBA 2018-2019 Regular Season  21800001  10/16/2018     203967
# 1   NBA 2018-2019 Regular Season  21800001  10/16/2018     203496
# 2   NBA 2018-2019 Regular Season  21800001  10/16/2018     203954
# 3   NBA 2018-2019 Regular Season  21800001  10/16/2018    1628365
# 4   NBA 2018-2019 Regular Season  21800001  10/16/2018    1627732
# ..                           ...       ...         ...        ...
# 81  NBA 2018-2019 Regular Season  21800004  10/17/2018     204038
# 82  NBA 2018-2019 Regular Season  21800004  10/17/2018     203922
# 83  NBA 2018-2019 Regular Season  21800004  10/17/2018     202397
# 84  NBA 2018-2019 Regular Season  21800004  10/17/2018       2585
# 85  NBA 2018-2019 Regular Season  21800004  10/17/2018    1629155
#
#              FULL NAME POSITION       OWNTEAM OPPONENTTEAM VENUE STARTER  ...  \
# 0          Dario Saric        F  Philadelphia       Boston     R       Y  ...
# ...

# %%
data.columns
# Out:
# Index(['DATASET', 'GAME-ID', 'DATE', 'PLAYER-ID', 'FULL NAME', 'POSITION',
#        'OWNTEAM', 'OPPONENTTEAM', 'VENUE', 'STARTER', 'MIN', 'FG', 'FGA', '3P',
#        '3PA', 'FT', 'FTA', 'OR', 'DR', 'TOT', 'A', 'PF', 'ST', 'TO', 'BL',
#        'PTS', 'USAGERATE', 'REST[1]'],
#       dtype='object')

# %%
ggplot(data, aes(x="DATE", fill="OWNTEAM")) + geom_bar()
# Out:
# <ggplot: (8789209358089)>
